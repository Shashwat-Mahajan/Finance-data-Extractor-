# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3.2:1b", temperature=1.8,num_predict=2)
llm.invoke("The first person to go to moon was")
# Out:
# AIMessage(content='Neil Armstrong', additional_kwargs={}, response_metadata={'model': 'llama3.2:1b', 'created_at': '2026-03-21T18:29:04.7749366Z', 'done': True, 'done_reason': 'length', 'total_duration': 462116800, 'load_duration': 204043600, 'prompt_eval_count': 33, 'prompt_eval_duration': 239529700, 'eval_count': 2, 'eval_duration': 13647000, 'logprobs': None, 'model_name': 'llama3.2:1b', 'model_provider': 'ollama'}, id='lc_run--019d11a8-6eae-7701-ae78-7ed92c1bf96a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 33, 'output_tokens': 2, 'total_tokens': 35})

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model_name="mixtral-8x7b-32768",api_key)
llm.invoke("The first person to go to moon was")
# Out:
# ---------------------------------------------------------------------------
# GroqError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 from langchain_groq import ChatGroq
# ----> 2 llm = ChatGroq(model_name="mixtral-8x7b-32768")
#       3 llm.invoke("The first person to go to moon was")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_groq\chat_models.py:520, in ChatGroq.validate_environment(self)
#     518 sync_specific: dict[str, Any] = {"http_client": self.http_client}
#     519 if not self.client:
# --> 520     self.client = groq.Groq(
#     521         **client_params, **sync_specific
#     522     ).chat.completions
#     523 if not self.async_client:
#     524     async_specific: dict[str, Any] = {"http_client": self.http_async_client}
#
# File ~\AppData\Roaming\Python\Python312\site-packages\groq\_client.py:79, in Groq.__init__(self, api_key, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#      77     api_key = os.environ.get("GROQ_API_KEY")
#      78 if api_key is None:
# ---> 79     raise GroqError(
#      80         "The api_key client option must be set either by passing api_key to the client or by setting the GROQ_API_KEY environment variable"
#      81     )
#      82 self.api_key = api_key
#      84 if base_url is None:
#
# GroqError: The api_key client option must be set either by passing api_key to the client or by setting the GROQ_API_KEY environment variable
